# %%
import os
import pandas as pd
import shutil
train_dir_path = "./archive/Train"
test_dir_path = "./archive/Test"
train_df = pd.read_csv(train_dir_path+".csv")
test_df = pd.read_csv(test_dir_path+".csv")
extracted_train_dir = "extracted_Train"
extracted_test_dir = "extracted_Test"
labels = [0,2,15,16,17,18]

folders = os.listdir(train_dir_path)
for folder in folders:
    if folder != ".DS_Store" and folder != ".tmp.driveupload":
        if int(train_df[train_df["video_id"]==int(folder)]["label_id"]) in labels:
            dir_path = shutil.copytree(train_dir_path+"/"+folder,extracted_train_dir+"/"+folder)
            print(dir_path)
# Out:
# /var/folders/pg/4hhw280s6ps05y76rc9s9vgm0000gq/T/ipykernel_4191/3536905013.py:15: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   if int(train_df[train_df["video_id"]==int(folder)]["label_id"]) in labels:
# extracted_Train/86062
# extracted_Train/128857
# extracted_Train/127023
# extracted_Train/74947
# extracted_Train/107424
# extracted_Train/30039
# extracted_Train/29928
# extracted_Train/114033
# extracted_Train/17429
# extracted_Train/141003
# extracted_Train/107616
# extracted_Train/124494
# extracted_Train/7990
# extracted_Train/87382
# extracted_Train/68716
# extracted_Train/37812
# extracted_Train/133047
# extracted_Train/111317
# extracted_Train/9452
# extracted_Train/146642
# extracted_Train/62648
# extracted_Train/100057
# extracted_Train/83346
# extracted_Train/86406
# extracted_Train/96694
# extracted_Train/35913
# extracted_Train/76248
# extracted_Train/92234
# ...

# %%
import os
import pandas as pd
import shutil
train_dir_path = "./archive/Train"
test_dir_path = "./archive/Test"
train_df = pd.read_csv(train_dir_path+".csv")
test_df = pd.read_csv(test_dir_path+".csv")
extracted_train_dir = "Train"
extracted_test_dir = "extracted_Test"
labels = [0,2,15,16,17,18]

folders = os.listdir(test_dir_path)
for folder in folders:
    if folder != ".DS_Store" and folder != ".tmp.driveupload":
        if int(test_df[test_df["video_id"]==int(folder)]["label_id"]) in labels:
            dir_path = shutil.copytree(test_dir_path+"/"+folder,extracted_test_dir+"/"+folder)
            print(dir_path)
# Out:
# /var/folders/pg/4hhw280s6ps05y76rc9s9vgm0000gq/T/ipykernel_4191/1279796387.py:15: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   if int(test_df[test_df["video_id"]==int(folder)]["label_id"]) in labels:
# extracted_Test/110493
# extracted_Test/51832
# extracted_Test/48775
# extracted_Test/95011
# extracted_Test/11940
# extracted_Test/109778
# extracted_Test/49237
# extracted_Test/119145
# extracted_Test/47702
# extracted_Test/16702
# extracted_Test/28831
# extracted_Test/25712
# extracted_Test/56684
# extracted_Test/14603
# extracted_Test/137070
# extracted_Test/20856
# extracted_Test/123470
# extracted_Test/94554
# extracted_Test/96203
# extracted_Test/22957
# extracted_Test/28663
# extracted_Test/48786
# extracted_Test/122132
# extracted_Test/4178
# extracted_Test/92233
# extracted_Test/18002
# extracted_Test/92465
# extracted_Test/89811
# extracted_Test/114808
# extracted_Test/37486
# ...

# %%
import os
folders = os.listdir("./reducated_Train")
print(len(folders))
folders = os.listdir("./reducated_Test")
print(len(folders))
# Out:
# 2661
# 388
